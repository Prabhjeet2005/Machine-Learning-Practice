# %%
import sys

# Reference Counting

a = []
print(sys.getrefcount(a))
# Out:
# 2

# %%
b = a
print(sys.getrefcount(a))
# Out:
# 3

# %% [markdown]
# # Garbage Collection

# %%
import gc

gc.enable()
# gc.disable()

print(gc.get_stats())
# Out:
# [{'collections': 231, 'collected': 1845, 'uncollectable': 0}, {'collections': 21, 'collected': 151, 'uncollectable': 0}, {'collections': 1, 'collected': 0, 'uncollectable': 0}]

# %% [markdown]
# # Profiling Memory usage With tracemalloc

# %%
import tracemalloc


def create_list():
    return [i for i in range(100)]


def main():
    tracemalloc.start()

    create_list()

    snapshot = tracemalloc.take_snapshot()
    top_stats = snapshot.statistics("lineno")

    print("[Top 10]")
    for stat in top_stats[:10]:
        print(stat)


main()
# Out:
# [Top 10]
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/site-packages/IPython/core/compilerop.py:86: size=14.5 KiB, count=150, average=99 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/site-packages/IPython/core/compilerop.py:174: size=9931 B, count=93, average=107 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/threading.py:272: size=3800 B, count=10, average=380 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/json/decoder.py:353: size=3725 B, count=34, average=110 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/codeop.py:118: size=2849 B, count=36, average=79 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/site-packages/jupyter_client/jsonutil.py:111: size=2250 B, count=45, average=50 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/site-packages/traitlets/traitlets.py:731: size=2193 B, count=34, average=64 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:45: size=2162 B, count=46, average=47 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/site-packages/traitlets/traitlets.py:1543: size=2057 B, count=33, average=62 B
# /Users/prabhjeet1/Desktop/PORTFOLIO/MachineLearning/venv/lib/python3.12/_weakrefset.py:88: size=1664 B, count=9, average=185 B
